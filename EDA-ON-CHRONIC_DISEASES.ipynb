# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings 
warning.filterwarnings('ignore')

# %%
df=pd.read_csv('kidney_disease.csv')
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (400, 26)

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  381.000000  383.000000  313.000000  312.000000  348.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437
# std     50.503006    5.741126   10.408752    3.193904    2.912587
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             391 non-null    float64
#  1   bp              388 non-null    float64
#  2   sg              353 non-null    float64
#  3   al              354 non-null    float64
#  4   su              351 non-null    float64
#  5   rbc             248 non-null    object
#  6   pc              335 non-null    object
#  7   pcc             396 non-null    object
#  8   ba              396 non-null    object
#  9   bgr             356 non-null    float64
#  10  bu              381 non-null    float64
#  11  sc              383 non-null    float64
#  12  sod             313 non-null    float64
#  13  pot             312 non-null    float64
#  14  hemo            348 non-null    float64
#  15  pcv             330 non-null    object
#  16  wc              295 non-null    object
# ...

# %%
df['pcv'].isna().sum()
# Out:
# 70

# %%
df['pcv']=pd.to_numeric(df['pcv'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             391 non-null    float64
#  1   bp              388 non-null    float64
#  2   sg              353 non-null    float64
#  3   al              354 non-null    float64
#  4   su              351 non-null    float64
#  5   rbc             248 non-null    object
#  6   pc              335 non-null    object
#  7   pcc             396 non-null    object
#  8   ba              396 non-null    object
#  9   bgr             356 non-null    float64
#  10  bu              381 non-null    float64
#  11  sc              383 non-null    float64
#  12  sod             313 non-null    float64
#  13  pot             312 non-null    float64
#  14  hemo            348 non-null    float64
#  15  pcv             329 non-null    float64
#  16  wc              295 non-null    object
# ...

# %%
df['wc']=pd.to_numeric(df['wc'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             391 non-null    float64
#  1   bp              388 non-null    float64
#  2   sg              353 non-null    float64
#  3   al              354 non-null    float64
#  4   su              351 non-null    float64
#  5   rbc             248 non-null    object
#  6   pc              335 non-null    object
#  7   pcc             396 non-null    object
#  8   ba              396 non-null    object
#  9   bgr             356 non-null    float64
#  10  bu              381 non-null    float64
#  11  sc              383 non-null    float64
#  12  sod             313 non-null    float64
#  13  pot             312 non-null    float64
#  14  hemo            348 non-null    float64
#  15  pcv             329 non-null    float64
#  16  wc              294 non-null    float64
# ...

# %%
df['rc']=pd.to_numeric(df['rc'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             391 non-null    float64
#  1   bp              388 non-null    float64
#  2   sg              353 non-null    float64
#  3   al              354 non-null    float64
#  4   su              351 non-null    float64
#  5   rbc             248 non-null    object
#  6   pc              335 non-null    object
#  7   pcc             396 non-null    object
#  8   ba              396 non-null    object
#  9   bgr             356 non-null    float64
#  10  bu              381 non-null    float64
#  11  sc              383 non-null    float64
#  12  sod             313 non-null    float64
#  13  pot             312 non-null    float64
#  14  hemo            348 non-null    float64
#  15  pcv             329 non-null    float64
#  16  wc              294 non-null    float64
# ...

# %%
cats_col=[col for col in df.columns if df[col].dtype =='object']
nums_col=[col for col in df.columns if df[col].dtype !='object']

# %%
for col in cats_col:
    print(f"{col} has {df[col].unique()} values \n")
# Out:
# rbc has [nan 'normal' 'abnormal'] values
#
# pc has ['normal' 'abnormal' nan] values
#
# pcc has ['notpresent' 'present' nan] values
#
# ba has ['notpresent' 'present' nan] values
#
# htn has ['yes' 'no' nan] values
#
# dm has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# cad has ['no' 'yes' '\tno' nan] values
#
# appet has ['good' 'poor' nan] values
#
# pe has ['no' 'yes' nan] values
#
# ane has ['no' 'yes' nan] values
#
# classification has ['ckd' 'ckd\t' 'notckd'] values

# %%
#replace unwanted values
df['dm'].replace(to_replace={' yes':'yes', '\tyes': 'yes','\tno':'no'},inplace=True)

# %%
df['dm'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df['cad']=df['cad'].replace(to_replace={'\tno': 'no'})

# %%
df['cad'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df['classification'].replace(to_replace={'ckd\t': 'ckd',},inplace=True)

# %%
df['classification'].unique()
# Out:
# array(['ckd', 'notckd'], dtype=object)

# %%
df['classification']=df['classification'].map({'ckd':0,'notckd':1})

# %%
#univariate 
plt.figure(figsize=(10,6))
sns.histplot(df['age'].dropna(),kde=True,bins=20,color='skyblue')
plt.title('Dist of age')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.countplot(x='htn',data=df,palette='viridis')
# Out:
# C:\Users\91879\AppData\Local\Temp\ipykernel_18700\4040993376.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='htn',data=df,palette='viridis')
# <Axes: xlabel='htn', ylabel='count'>

# %%
#insights: 150 have a hypertension 
# 250 has not a hypertension

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.boxplot(x='classification', y='bu',data=df,palette='viridis')
# Out:
# C:\Users\91879\AppData\Local\Temp\ipykernel_18700\3830046859.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='classification', y='bu',data=df,palette='viridis')
# <Axes: xlabel='classification', ylabel='bu'>

# %%
sns.violinplot(x='classification',y='sc',data=df,palette='muted')
# Out:
# C:\Users\91879\AppData\Local\Temp\ipykernel_18700\1429445133.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='classification',y='sc',data=df,palette='muted')
# <Axes: xlabel='classification', ylabel='sc'>

# %%
sns.countplot(x='ane',data=df)
# Out:
# <Axes: xlabel='ane', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.appet.value_counts().plot.pie(autopct='%1.1f',explode=(0,0.1),startangle=90,shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.histplot(df['wc'].dropna(),bins=20,kde=True)
# Out:
# <Axes: xlabel='wc', ylabel='Count'>

# %%
df['dm'].value_counts().plot.pie(autopct="%1.1f%%",wedgeprops=dict(width=0.3))
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x='cad',data=df)
# Out:
# <Axes: xlabel='cad', ylabel='count'>

# %%
#bivariate analysis

# %%
sns.scatterplot(x='age',y='bp',data=df)
# Out:
# <Axes: xlabel='age', ylabel='bp'>

# %%
sns.scatterplot(x='age',y='bp',data=df,hue='classification',palette='coolwarm')
# Out:
# <Axes: xlabel='age', ylabel='bp'>

# %%
sns.scatterplot(x='age',y='bp',data=df)
# Out:
# <Axes: xlabel='dm', ylabel='al'>

# %%
#stacked bar chart
diabetes_hypertension=pd.crosstab(df['dm'],df['htn'])

# %%
diabetes_hypertension
# Out:
# htn   no  yes
# dm
# no   220   41
# yes   31  106

# %%
diabetes_hypertension.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='dm'>

# %%
cols=['age','bp','bgr','sc','classification']

g = sns.PairGrid(df[cols],hue='classification',palette='coolwarm')
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot,cmap='Blues_d')
g.map_diag(sns.histplot)
g.add_legend()
plt.title("PairGrid for selected columns")
plt.show()
# Out:
# C:\Users\91879\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# C:\Users\91879\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# C:\Users\91879\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# C:\Users\91879\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# C:\Users\91879\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
# ...

# %%
corr=df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot=True,cmap='coolwarm',linewidth=.5)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                71
# wc                106
# rc                131
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
nums_col
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'rc']

# %%
median_values=df[nums_col].median()

# %%
median_values
# Out:
# age       55.00
# bp        80.00
# sg         1.02
# al         0.00
# su         0.00
# bgr      121.00
# bu        42.00
# sc         1.30
# sod      138.00
# pot        4.40
# hemo      12.65
# pcv       40.00
# wc      8000.00
# rc         4.80
# dtype: float64

# %%
df[nums_col]=df[nums_col].fillna(median_values)

# %%
df[nums_col].isna().sum()
# Out:
# age     0
# bp      0
# sg      0
# al      0
# su      0
# bgr     0
# bu      0
# sc      0
# sod     0
# pot     0
# hemo    0
# pcv     0
# wc      0
# rc      0
# dtype: int64

# %%
mode_values=df.mode().iloc[0]

# %%
df[cats_col]=df[cats_col].fillna(mode_values)

# %%
df[cats_col].isna().sum()
# Out:
# rbc               0
# pc                0
# pcc               0
# ba                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LabelEncoder=LabelEncoder()
for col in cats_col:
    df[col]=LabelEncoder.fit_transform(df[col])

# %%
df.head()
# Out:
#     age    bp     sg   al   su  rbc  pc  pcc  ba    bgr  ...   pcv      wc  \
# 0  48.0  80.0  1.020  1.0  0.0    1   1    0   0  121.0  ...  44.0  7800.0
# 1   7.0  50.0  1.020  4.0  0.0    1   1    0   0  121.0  ...  38.0  6000.0
# 2  62.0  80.0  1.010  2.0  3.0    1   1    0   0  423.0  ...  31.0  7500.0
# 3  48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 4  51.0  80.0  1.010  2.0  0.0    1   1    0   0  106.0  ...  35.0  7300.0
#
#     rc  htn  dm  cad  appet  pe  ane  classification
# 0  5.2    1   1    0      0   0    0               0
# 1  4.8    0   0    0      0   0    0               0
# 2  4.8    0   1    0      1   0    1               0
# 3  3.9    1   0    0      1   1    1               0
# 4  4.6    0   0    0      0   0    0               0
#
# [5 rows x 25 columns]
